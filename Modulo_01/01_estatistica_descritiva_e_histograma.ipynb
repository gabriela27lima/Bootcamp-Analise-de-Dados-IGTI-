# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#leitura de documento .csv
clientes = pd.read_csv('clientes_8000.csv', sep =';')

# %%
# Resumo de estatística descritiva de variáveis quantitativas
print(clientes.describe())
# Out:
#              idade  anos_estudo  qtde_filhos       salario
# count  7999.000000  7999.000000  7997.000000   7999.000000
# mean     38.477060    10.067633     2.404902   3169.312664
# std      13.568667     2.537797     1.704059   3055.862493
# min      17.000000     1.000000     0.000000      0.000000
# 25%      28.000000     9.000000     1.000000   1100.000000
# 50%      37.000000    10.000000     2.000000   2410.000000
# 75%      47.000000    12.000000     4.000000   3640.500000
# max      90.000000    16.000000     5.000000  19994.000000

# %%
#Criação de Histograma 2 variáveis quantitativas :)
clientes.idade.hist(bins=100) #ainda não descobri para que serve o bins, mas sempre modifico rs
plt.xlabel ('Idade') # título do eixo X
plt.ylabel ('Número de Clientes') # título do eixo y
plt. title ('Distribuição de Idades') #título do gráfico
plt.show() #visualização do histograma
